# %%
import numpy as np
import pandas as pd

# %%
dates=pd.read_csv("dim_date.csv")

# %%
hotels=pd.read_csv("dim_hotels.csv")

# %%
rooms_type=pd.read_csv("dim_rooms.csv")

# %%
bookings=pd.read_csv("fact_aggregated_bookings.csv")

# %%
bookings_det=pd.read_csv("fact_bookings.csv")

# %%
dates.shape
# Out:
# (92, 4)

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
bookings_det.shape
# Out:
# (134590, 12)

# %%
bookings_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  int64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 359.5+ KB

# %%
bookings_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  int64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      134590 non-null  float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
grouped = bookings_det.groupby('property_id')

# %%
bookings_det['ratings_given'] = grouped['ratings_given'].transform(lambda x: x.fillna(x.mean()))

# %%
bookings_det[(bookings_det['property_id'] == 16558) & (bookings_det['booking_status'] == 'Cancelled')]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 6        May012216558RT17        16558   2022-04-28    2022-05-01
# 13      May012216558RT114        16558   2022-04-30    2022-05-01
# 21       May012216558RT24        16558   2022-04-29    2022-05-01
# ...                   ...          ...          ...           ...
# 132961   Jul312216558RT27        16558   2022-07-28    2022-07-31
# 132963   Jul312216558RT29        16558   2022-07-26    2022-07-31
# 132970   Jul312216558RT32        16558   2022-07-26    2022-07-31
# 132973   Jul312216558RT35        16558   2022-07-29    2022-07-31
# 132974   Jul312216558RT36        16558   2022-07-27    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1         2022-05-02          2           RT1           others              4
# ...

# %%
bookings_det[(bookings_det['property_id'] == 16559) & (bookings_det['booking_status'] == 'Cancelled')]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 52       May012216559RT13        16559   2022-04-27    2022-05-01
# 57       May012216559RT18        16559   2022-04-28    2022-05-01
# 62      May012216559RT113        16559   2022-04-26    2022-05-01
# 65      May012216559RT116        16559   2022-04-27    2022-05-01
# 66      May012216559RT117        16559   2022-04-25    2022-05-01
# ...                   ...          ...          ...           ...
# 133048  Jul312216559RT319        16559   2022-07-29    2022-07-31
# 133049  Jul312216559RT320        16559   2022-07-29    2022-07-31
# 133050  Jul312216559RT321        16559   2022-07-29    2022-07-31
# 133053   Jul312216559RT42        16559   2022-07-29    2022-07-31
# 133062  Jul312216559RT411        16559   2022-07-27    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 52        2022-05-02          1           RT1         tripster              4
# ...

# %%
bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 359.5+ KB

# %%
bookings.head(10)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559     01-May-22           RT1                   25        30
# 1        19562     01-May-22           RT1                   28        30
# 2        19563     01-May-22           RT1                   23        30
# 3        17558     01-May-22           RT1                   13        19
# 4        16558     01-May-22           RT1                   18        19
# 5        17560     01-May-22           RT1                   28        40
# 6        19558     01-May-22           RT1                   25        40
# 7        19560     01-May-22           RT1                   23        26
# 8        17561     01-May-22           RT1                   22        26
# 9        16560     01-May-22           RT1                   24        34

# %%
bookings.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4

# %%
bookings_det.head(20)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 0    May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1    May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2    May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3    May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4    May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
# 5    May012216558RT16        16558   2022-05-01    2022-05-01    2022-05-03
# 6    May012216558RT17        16558   2022-04-28    2022-05-01    2022-05-06
# 7    May012216558RT18        16558   2022-04-26    2022-05-01    2022-05-03
# 8    May012216558RT19        16558   2022-04-30    2022-05-01    2022-05-02
# 9   May012216558RT110        16558   2022-04-28    2022-05-01    2022-05-02
# 10  May012216558RT111        16558   2022-04-29    2022-05-01    2022-05-07
# ...

# %%
rating_all=bookings_det['ratings_given'].mean()

# %%
rating_all
# Out:
# 3.620028519090789

# %%
ratings_ind=grouped['ratings_given'].mean()
ratings_ind
# Out:
# property_id
# 16558    4.105931
# 16559    4.135868
# 16560    3.005966
# 16561    4.116569
# 16562    3.028423
# 16563    4.112075
# 17558    3.021446
# 17559    4.135949
# 17560    3.014968
# 17561    4.126375
# 17562    2.150993
# 17563    4.121193
# 17564    2.123807
# 18558    3.029721
# 18559    2.139269
# 18560    4.113136
# 18561    4.103283
# 18562    4.126688
# 18563    3.029399
# 19558    2.154198
# 19559    3.019766
# 19560    4.117745
# 19561    3.032775
# 19562    4.116655
# 19563    3.008129
# Name: ratings_given, dtype: float64

# %%
bookings_det['ratings_given']=bookings_det['ratings_given'].astype(int)

# %%
bookings_det.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online              1    Checked Out
# 1          2           RT1           others              4      Cancelled
# 2          2           RT1          logtrip              5    Checked Out
# 3          2           RT1           others              4      Cancelled
# 4          4           RT1    direct online              5    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
bookings_det.to_csv("updated_bookings")

# %%
bookings_det.to_csv("updated.csv",index=False)
